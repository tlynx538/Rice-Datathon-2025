# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../../data/processed/encoded_dataset-non-impute.csv",index_col=0)

# %%
df.head()
# Out:
#       GVWR Class  Model Year  Electric Mile Range  \
# Date
# 2019           0        2020                    0
# 2020           0        2020                    0
# 2021           0        2020                    0
# 2019           0        2019                    0
# 2019           0        2018                    0
#
#       Number of Vehicles Registered at the Same Address  Vehicle Population  \
# Date
# 2019                                                  4              395883
# 2020                                                  1              370954
# 2021                                                  1              349406
# 2019                                                  4              348475
# 2019                                                  4              333296
#
#       Vehicle Category_BS  Vehicle Category_BT  Vehicle Category_MC  \
# Date
# 2019                False                False                False
# ...

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_0fe8b_row0_col0, #T_0fe8b_row1_col1, #T_0fe8b_row2_col2, #T_0fe8b_row3_col3, #T_0fe8b_row4_col4, #T_0fe8b_row5_col5, #T_0fe8b_row6_col6, #T_0fe8b_row7_col7, #T_0fe8b_row8_col8, #T_0fe8b_row9_col9, #T_0fe8b_row10_col10, #T_0fe8b_row11_col11, #T_0fe8b_row12_col12, #T_0fe8b_row13_col13, #T_0fe8b_row14_col14, #T_0fe8b_row15_col15, #T_0fe8b_row16_col16, #T_0fe8b_row17_col17, #T_0fe8b_row18_col18, #T_0fe8b_row19_col19, #T_0fe8b_row19_col22, #T_0fe8b_row20_col20, #T_0fe8b_row21_col21, #T_0fe8b_row22_col19, #T_0fe8b_row22_col22, #T_0fe8b_row23_col23, #T_0fe8b_row24_col24 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0fe8b_row0_col1, #T_0fe8b_row5_col1, #T_0fe8b_row14_col1, #T_0fe8b_row17_col11, #T_0fe8b_row20_col12, #T_0fe8b_row21_col2 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# ...

# %%
# drop features with bad correlations
df = df.drop(['Fuel Type_Electric','Fuel Technology_ICE', 'Fuel Type_Hydrogen', 'Fuel Technology_FCEV'],axis=1)

# %%
df.to_csv("../../data/processed/removed-unn-corr.csv")
