# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import root_mean_squared_error
import numpy as np
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("../../data/encoded.csv")

# %%
df.head()
# Out:
#    Date  Model Year  Electric Mile Range  \
# 0  2019        2020                    0
# 1  2020        2020                    0
# 2  2021        2020                    0
# 3  2019        2019                    0
# 4  2019        2018                    0
#
#    Number of Vehicles Registered at the Same Address  Vehicle Population  \
# 0                                                  4              395883
# 1                                                  1              370954
# 2                                                  1              349406
# 3                                                  4              348475
# 4                                                  4              333296
#
#    GVWR_Heavy-Duty  GVWR_Light-Duty  GVWR_Medium-Duty  GVWR_Not Applicable  \
# 0            False            False             False                 True
# 1            False            False             False                 True
# 2            False            False             False                 True
# 3            False            False             False                 True
# 4            False            False             False                 True
#
#    GVWR_Unknown  ...  Vehicle Category_T6  Vehicle Category_T7  \
# 0         False  ...                False                False
# 1         False  ...                False                False
# 2         False  ...                False                False
# 3         False  ...                False                False
# 4         False  ...                False                False
#
#    Fuel Type_Electric  Fuel Type_Gasoline  Fuel Type_Hydrogen  \
# 0               False                True               False
# 1               False                True               False
# 2               False                True               False
# 3               False                True               False
# 4               False                True               False
#
#    Fuel Type_Natural Gas  Fuel Type_Unknown  Fuel Technology_FCEV  \
# 0                  False              False                 False
# 1                  False              False                 False
# 2                  False              False                 False
# 3                  False              False                 False
# 4                  False              False                 False
#
#    Fuel Technology_ICE  Fuel Technology_PHEV
# 0                 True                 False
# 1                 True                 False
# 2                 True                 False
# 3                 True                 False
# 4                 True                 False
#
# [5 rows x 30 columns]

# %%
X = df.drop(['Vehicle Population'],axis=1)

# %%
y = df['Vehicle Population']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1675)

# %%
model = DecisionTreeRegressor(    
    criterion='squared_error', 
    max_depth=100,
    random_state=42)

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=100, random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
print(f"RMSE: {root_mean_squared_error(y_test, y_pred)}")
print(f"R²: {r2_score(y_test, y_pred)}")
# Out:
# RMSE: 5991.784323449261
# R²: 0.8868539851764248
