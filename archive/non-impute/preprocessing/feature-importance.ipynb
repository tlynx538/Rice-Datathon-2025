# %%
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import root_mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns

# %%
df = pd.read_csv("../../data/encoded.csv")

# %%
corr = df.corr()
corr.style.background_gradient(cmap='Pastel1')
# Out:
# <style type="text/css">
# #T_350cd_row0_col0, #T_350cd_row1_col1, #T_350cd_row2_col2, #T_350cd_row3_col3, #T_350cd_row4_col4, #T_350cd_row5_col5, #T_350cd_row6_col6, #T_350cd_row7_col7, #T_350cd_row8_col8, #T_350cd_row9_col9, #T_350cd_row10_col10, #T_350cd_row11_col11, #T_350cd_row12_col12, #T_350cd_row13_col13, #T_350cd_row14_col14, #T_350cd_row15_col15, #T_350cd_row16_col16, #T_350cd_row17_col17, #T_350cd_row18_col18, #T_350cd_row19_col19, #T_350cd_row20_col20, #T_350cd_row21_col21, #T_350cd_row22_col22, #T_350cd_row23_col23, #T_350cd_row24_col24, #T_350cd_row24_col27, #T_350cd_row25_col25, #T_350cd_row26_col26, #T_350cd_row27_col24, #T_350cd_row27_col27, #T_350cd_row28_col28, #T_350cd_row29_col29 {
#   background-color: #f2f2f2;
#   color: #000000;
# }
# #T_350cd_row0_col1, #T_350cd_row0_col6, #T_350cd_row0_col7, #T_350cd_row0_col8, #T_350cd_row0_col9, #T_350cd_row0_col14, #T_350cd_row0_col20, #T_350cd_row0_col25, #T_350cd_row0_col29, #T_350cd_row1_col2, #T_350cd_row1_col6, #T_350cd_row1_col7, #T_350cd_row1_col8, #T_350cd_row1_col14, #T_350cd_row1_col20, #T_350cd_row2_col1, #T_350cd_row2_col6, #T_350cd_row2_col7, #T_350cd_row2_col8, #T_350cd_row2_col20, #T_350cd_row2_col23, #T_350cd_row3_col6, #T_350cd_row3_col7, #T_350cd_row3_col8, #T_350cd_row3_col9, #T_350cd_row3_col14, #T_350cd_row3_col20, #T_350cd_row3_col25, #T_350cd_row3_col29, #T_350cd_row4_col1, #T_350cd_row4_col6, #T_350cd_row4_col8, #T_350cd_row4_col16, #T_350cd_row4_col29, #T_350cd_row5_col25, #T_350cd_row5_col29, #T_350cd_row6_col23, #T_350cd_row6_col29, #T_350cd_row7_col23, #T_350cd_row8_col25, #T_350cd_row8_col29, #T_350cd_row9_col20, #T_350cd_row9_col23, #T_350cd_row9_col29, #T_350cd_row10_col25, #T_350cd_row10_col29, #T_350cd_row11_col25, #T_350cd_row11_col29, #T_350cd_row12_col23, #T_350cd_row12_col29, #T_350cd_row13_col23, #T_350cd_row13_col29, #T_350cd_row14_col2, #T_350cd_row14_col4, #T_350cd_row14_col24, #T_350cd_row14_col25, #T_350cd_row14_col27, #T_350cd_row14_col28, #T_350cd_row15_col23, #T_350cd_row15_col29, #T_350cd_row16_col23, #T_350cd_row16_col29, #T_350cd_row17_col23, #T_350cd_row17_col25, #T_350cd_row17_col29, #T_350cd_row18_col23, #T_350cd_row18_col25, #T_350cd_row18_col29, #T_350cd_row19_col23, #T_350cd_row19_col29, #T_350cd_row20_col9, #T_350cd_row21_col25, #T_350cd_row21_col29, #T_350cd_row22_col1, #T_350cd_row22_col9, #T_350cd_row22_col15, #T_350cd_row22_col29, #T_350cd_row23_col4, #T_
# %%
model = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
X = df.drop(['Vehicle Population'],axis=1)

# %%
y = df['Vehicle Population']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
model.fit(X_train,y_train)

# %%
# Evaluate
y_pred = model.predict(X_test)
print(f"RMSE: {root_mean_squared_error(y_test, y_pred)}")
print(f"R²: {r2_score(y_test, y_pred)}")

# %%
feature_importances = model.feature_importances_
feature_names = X_train.columns

# %%
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# Plot the feature importance
plt.figure(figsize=(12, 6))
plt.bar(importance_df['Feature'], importance_df['Importance'])
plt.xlabel('Feature')
plt.ylabel('Importance Score')
plt.title('Random Forest Feature Importance')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# !pip install weasyprint
# Out:
# Collecting weasyprint
#   Downloading weasyprint-64.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting pydyf>=0.11.0 (from weasyprint)
#   Downloading pydyf-0.11.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: cffi>=0.6 in /Users/vjaiwantx/projects/chevron-ev-production/env/lib/python3.13/site-packages (from weasyprint) (1.17.1)
# Collecting tinyhtml5>=2.0.0b1 (from weasyprint)
#   Downloading tinyhtml5-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: tinycss2>=1.4.0 in /Users/vjaiwantx/projects/chevron-ev-production/env/lib/python3.13/site-packages (from weasyprint) (1.4.0)
# Collecting cssselect2>=0.1 (from weasyprint)
#   Downloading cssselect2-0.7.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting Pyphen>=0.9.1 (from weasyprint)
#   Downloading pyphen-0.17.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: Pillow>=9.1.0 in /Users/vjaiwantx/projects/chevron-ev-production/env/lib/python3.13/site-packages (from weasyprint) (11.1.0)
# Requirement already satisfied: fonttools>=4.0.0 in /Users/vjaiwantx/projects/chevron-ev-production/env/lib/python3.13/site-packages (from fonttools[woff]>=4.0.0->weasyprint) (4.55.8)
# Requirement already satisfied: pycparser in /Users/vjaiwantx/projects/chevron-ev-production/env/lib/python3.13/site-packages (from cffi>=0.6->weasyprint) (2.22)
# Requirement already satisfied: webencodings in /Users/vjaiwantx/projects/chevron-ev-production/env/lib/python3.13/site-packages (from cssselect2>=0.1->weasyprint) (0.5.1)
# Collecting brotli>=1.0.1 (from fonttools[woff]>=4.0.0->weasyprint)
#   Downloading Brotli-1.1.0-cp313-cp313-macosx_10_13_universal2.whl.metadata (5.5 kB)
# Collecting zopfli>=0.1.4 (from fonttools[woff]>=4.0.0->weasyprint)
#   Downloading zopfli-0.2.3.post1-cp313-cp313-macosx_10_13_universal2.whl.metadata (2.9 kB)
# Downloading weasyprint-64.0-py3-none-any.whl (301 kB)
# Downloading cssselect2-0.7.0-py3-none-any.whl (15 kB)
# Downloading pydyf-0.11.0-py3-none-any.whl (8.1 kB)
# Downloading pyphen-0.17.2-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.7 MB/s eta 0:00:000 MB/s eta 0:00:01
# Downloading tinyhtml5-2.0.0-py3-none-any.whl (39 kB)
# Downloading Brotli-1.1.0-cp313-cp313-macosx_10_13_universal2.whl (815 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.7/815.7 kB 12.0 MB/s eta 0:00:00
# Downloading zopfli-0.2.3.post1-cp313-cp313-macosx_10_13_universal2.whl (295 kB)
# Installing collected packages: brotli, zopfli, tinyhtml5, Pyphen, pydyf, cssselect2, weasyprint
# Successfully installed Pyphen-0.17.2 brotli-1.1.0 cssselect2-0.7.0 pydyf-0.11.0 tinyhtml5-2.0.0 weasyprint-64.0 zopfli-0.2.3.post1
