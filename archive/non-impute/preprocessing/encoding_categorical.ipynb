# %% [markdown]
# ### Need to convert the preprocessing part as function later!

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("../../../data/cleaned.csv")

# %%
df.head()
# Out:
#    Date Vehicle Category      GVWR Class Fuel Type  Model Year  \
# 0  2019                P  Not Applicable  Gasoline        2020
# 1  2020                P  Not Applicable  Gasoline        2020
# 2  2021                P  Not Applicable  Gasoline        2020
# 3  2019                P  Not Applicable  Gasoline        2019
# 4  2019                P  Not Applicable  Gasoline        2018
#
#   Fuel Technology Electric Mile Range  \
# 0             ICE      Not Applicable
# 1             ICE      Not Applicable
# 2             ICE      Not Applicable
# 3             ICE      Not Applicable
# 4             ICE      Not Applicable
#
#   Number of Vehicles Registered at the Same Address     Region  \
# 0                                                ≥4  Statewide
# 1                                                 1  Statewide
# 2                                                 1  Statewide
# 3                                                ≥4  Statewide
# ...

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x=df['Vehicle Category'], palette='coolwarm')
plt.title('Vehicle Category Distribution')
plt.xlabel("Vehicle Categories")
plt.ylabel("Counts")
plt.show()
# Out:
# /var/folders/bn/r6lyl28n33s5ppx49dq2jh400000gn/T/ipykernel_81755/635954810.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['Vehicle Category'], palette='coolwarm')

# %% [markdown]
# [](![image.png](attachment:c60f55c2-81ca-41bb-aba7-52628b013b7c.png)![image.png](attachment:adc8ff43-2b61-49a8-acb9-dc4f1f6fa93e.png)

# %%
df[df['Vehicle Category'] == 'T6']
# Out:
#        Date Vehicle Category GVWR Class Fuel Type  Model Year Fuel Technology  \
# 2327   2023               T6    Unknown  Gasoline        1979             ICE
# 2766   2023               T6          5    Diesel        2021             ICE
# 2781   2022               T6          5    Diesel        2021             ICE
# 2836   2021               T6          5    Diesel        2021             ICE
# 2967   2023               T6          5    Diesel        2022             ICE
# ...     ...              ...        ...       ...         ...             ...
# 40214  2019               T6          6    Diesel        1977             ICE
# 40215  2019               T6          4    Diesel        1976             ICE
# 40216  2019               T6          7    Diesel        1976             ICE
# 40217  2019               T6          4    Diesel        1975             ICE
# 40218  2019               T6          7    Diesel        1975             ICE
#
# ...

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x=df['GVWR Class'], palette='coolwarm')
plt.title('GVWR Class Distribution')
plt.xlabel("GVWR Class")
plt.ylabel("Counts")
plt.show()
# Out:
# /var/folders/bn/r6lyl28n33s5ppx49dq2jh400000gn/T/ipykernel_81755/3319720844.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['GVWR Class'], palette='coolwarm')

# %% [markdown]
# #### Gross Vehicle Weight Rating or the amount of weight that your vehicle can safely handle

# %%
# Count fuel type occurrences per year
fuel_trend = df.groupby(["Date", "Fuel Type"]).size().unstack().fillna(0)

# Plot
plt.figure(figsize=(10, 6))
sns.lineplot(data=fuel_trend, marker="o")

# Labels
plt.xlabel("Year")
plt.ylabel("Count of Vehicles")
plt.title("Trend of Fuel Type Distribution Over Time")
plt.legend(title="Fuel Type")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x=df['Fuel Type'], palette='coolwarm')
plt.title('Fuel Type Distribution')
plt.xlabel("Fuel Types")
plt.ylabel("Counts")
plt.show()
# Out:
# /var/folders/bn/r6lyl28n33s5ppx49dq2jh400000gn/T/ipykernel_81755/189183764.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['Fuel Type'], palette='coolwarm')

# %%
plt.figure(figsize=(8, 5))
model_year = df['Model Year'].value_counts().sort_index()
sns.lineplot(x=model_year.index, y=model_year.values, marker="o", linewidth=2, color="b")
plt.xlabel("Year")
plt.ylabel("Count")
plt.title("Trend of Model Years of Cars")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x=df['Fuel Technology'], palette='coolwarm')
plt.title('Fuel Technology Distribution')
plt.xlabel("Fuel Technology Classification")
plt.ylabel("Counts")
plt.show()
# Out:
# /var/folders/bn/r6lyl28n33s5ppx49dq2jh400000gn/T/ipykernel_81755/2212942505.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['Fuel Technology'], palette='coolwarm')

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x=df['Electric Mile Range'], palette='coolwarm')
plt.title('Electric Mile Range Distribution')
plt.xlabel("Electric Mile Range")
plt.ylabel("Counts")
plt.show()
# Out:
# /var/folders/bn/r6lyl28n33s5ppx49dq2jh400000gn/T/ipykernel_81755/1864978035.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['Electric Mile Range'], palette='coolwarm')

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x=df['Region'], palette='coolwarm')
plt.title('Region Distribution')
plt.xlabel("Regions")
plt.ylabel("Counts")
plt.show()
# Out:
# /var/folders/bn/r6lyl28n33s5ppx49dq2jh400000gn/T/ipykernel_81755/1477834685.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['Region'], palette='coolwarm')

# %% [markdown]
# #### Since Regions is of only one category, it can be dropped

# %%
df['Date'] = df['Date'].astype('Int64')
df.set_index("Date", inplace=True)  # Set Date as index
plt.figure(figsize=(8, 5))
sns.lineplot(data=df, x=df.index, y="Vehicle Population", marker="o", linewidth=2, color="b")
plt.xlabel("Year")
plt.ylabel("Vehicle Population")
plt.title("Vehicle Population Over Time")
plt.grid(True)
plt.show()

# %%
df = df.drop(['Region'],axis=1)

# %%
df.head()
# Out:
#      Vehicle Category      GVWR Class Fuel Type  Model Year Fuel Technology  \
# Date
# 2019                P  Not Applicable  Gasoline        2020             ICE
# 2020                P  Not Applicable  Gasoline        2020             ICE
# 2021                P  Not Applicable  Gasoline        2020             ICE
# 2019                P  Not Applicable  Gasoline        2019             ICE
# 2019                P  Not Applicable  Gasoline        2018             ICE
#
#      Electric Mile Range Number of Vehicles Registered at the Same Address  \
# Date
# 2019      Not Applicable                                                ≥4
# 2020      Not Applicable                                                 1
# 2021      Not Applicable                                                 1
# 2019      Not Applicable                                                ≥4
# 2019      Not Applicable                                                ≥4
#
#       Vehicle Population
# Date
# ...

# %%
## Feature Engineering
# Adding Vehicle's age to dataframe
df['Vehicle Age'] = 2026 - df['Model Year']

# %%
df.head()
# Out:
#      Vehicle Category      GVWR Class Fuel Type  Model Year Fuel Technology  \
# Date
# 2019                P  Not Applicable  Gasoline        2020             ICE
# 2020                P  Not Applicable  Gasoline        2020             ICE
# 2021                P  Not Applicable  Gasoline        2020             ICE
# 2019                P  Not Applicable  Gasoline        2019             ICE
# 2019                P  Not Applicable  Gasoline        2018             ICE
#
#      Electric Mile Range Number of Vehicles Registered at the Same Address  \
# Date
# 2019      Not Applicable                                                ≥4
# 2020      Not Applicable                                                 1
# 2021      Not Applicable                                                 1
# 2019      Not Applicable                                                ≥4
# 2019      Not Applicable                                                ≥4
#
#       Vehicle Population  Vehicle Age
# ...

# %%
# Check for anomalies (negative ages)
anomalies = df[df['Vehicle Age'] < 0]

# Display summary statistics
print("Anomalies:\n", anomalies)
print("\nVehicle Age Summary:\n", df['Vehicle Age'].describe())
# Out:
# Anomalies:
#  Empty DataFrame
# Columns: [Vehicle Category, GVWR Class, Fuel Type, Model Year, Fuel Technology, Electric Mile Range, Number of Vehicles Registered at the Same Address, Vehicle Population, Vehicle Age]
# Index: []
#
# Vehicle Age Summary:
#  count    40450.000000
# mean        23.924129
# std         13.462658
# min          0.000000
# 25%         12.000000
# 50%         23.000000
# 75%         35.000000
# max         51.000000
# Name: Vehicle Age, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Vehicle Age'], bins=20, kde=True)
plt.title("Vehicle Age Distribution")
plt.xlabel("Vehicle Age (Years)")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Vehicle Age', y='Vehicle Population', data=df, alpha=0.5)
plt.title("Vehicle Age vs. Population")
plt.show()

# %%
# Set a clean, minimalistic style
sns.set(style="ticks")

# Plot the scatter plot
plt.figure(figsize=(10, 6))  # Larger figure for better readability
sns.scatterplot(x='Vehicle Age', y='Vehicle Population', data=df, alpha=0.5, color='b')

# Change the background color to light beige
plt.gcf().set_facecolor('#f4e1d2')  # Light brown color
plt.gca().set_facecolor('#f4e1d2')  # Light brown color for the plot area

# Refined plot title and labels
plt.title("Vehicle Age vs. Population", fontsize=16, color='darkblue', weight='normal')
plt.xlabel("Vehicle Age (Years)", fontsize=14, color='black', weight='normal')
plt.ylabel("Vehicle Population", fontsize=14, color='black', weight='normal')

# Customize the grid for better readability
plt.grid(True, linestyle='--', alpha=0.5)

# Tight layout for a clean finish
plt.tight_layout()

# Show the plot
plt.show()

# %%
gvwr_map = {
    '1': 'Light-Duty',
    '2': 'Light-Duty',
    '3': 'Medium-Duty',
    '4': 'Medium-Duty',
    '5': 'Medium-Duty',
    '6': 'Medium-Duty',
    '7': 'Heavy-Duty',
    '8': 'Heavy-Duty',
    'Not Applicable': 'Not Applicable',
    'Unknown': 'Unknown'
}

df['GVWR Group'] = df['GVWR Class'].map(gvwr_map)
df = pd.get_dummies(df, columns=['GVWR Group'], prefix='GVWR')

# %%
df = df.drop(['GVWR Class'],axis=1)
df = df.drop(['Vehicle Age'],axis=1)

# %%
# Define mappings for ordinal encoding
mile_range_mapping = {
    'Not Applicable': 0,
    '0 to 50 miles': 1,
    '51 to 100 miles': 2,
    '101 to 150 miles': 3,
    '>150 miles': 4,
    'Unknown': -1
}

vehicle_count_mapping = {
    '1': 1,
    '2': 2,
    '3': 3,
    '≥4': 4,
    'Unknown': -1
}

# Apply ordinal encoding
df['Electric Mile Range'] = df['Electric Mile Range'].map(mile_range_mapping)
df['Number of Vehicles Registered at the Same Address'] = df['Number of Vehicles Registered at the Same Address'].map(vehicle_count_mapping)

# %%
df = pd.get_dummies(df, columns=['Vehicle Category', 'Fuel Type', 'Fuel Technology'], drop_first=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.to_csv("../../data/encoded.csv")
#
# File ~/projects/Rice-Datathon-2025/env/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
df.columns
