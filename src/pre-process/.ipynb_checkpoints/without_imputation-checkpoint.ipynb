# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("../data/Chevron Challenge Materials/training.xlsx",index_col=0)

# %%
df.head()
# Out:
#      Vehicle Category      GVWR Class Fuel Type  Model Year Fuel Technology  \
# Date
# 2019                P  Not Applicable  Gasoline      2020.0             ICE
# 2020                P  Not Applicable  Gasoline      2020.0             ICE
# 2021                P  Not Applicable  Gasoline      2020.0             ICE
# 2019                P  Not Applicable  Gasoline      2019.0             ICE
# 2019                P  Not Applicable  Gasoline      2018.0             ICE
#
#      Electric Mile Range Number of Vehicles Registered at the Same Address  \
# Date
# 2019      Not Applicable                                                ≥4
# 2020      Not Applicable                                                 1
# 2021      Not Applicable                                                 1
# 2019      Not Applicable                                                ≥4
# 2019      Not Applicable                                                ≥4
#
#          Region  Vehicle Population
# Date
# ...

# %%
df.isna().any()
# Out:
# Vehicle Category                                     False
# GVWR Class                                           False
# Fuel Type                                            False
# Model Year                                            True
# Fuel Technology                                      False
# Electric Mile Range                                  False
# Number of Vehicles Registered at the Same Address    False
# Region                                               False
# Vehicle Population                                   False
# dtype: bool

# %%
df[df['Model Year'].isna() == True]
# Out:
#      Vehicle Category      GVWR Class Fuel Type  Model Year Fuel Technology  \
# Date
# 2020                P  Not Applicable  Gasoline         NaN             ICE
# 2020               MC  Not Applicable  Gasoline         NaN             ICE
# 2020                P  Not Applicable  Gasoline         NaN             ICE
# 2020                P  Not Applicable  Gasoline         NaN             ICE
# 2020                P  Not Applicable  Gasoline         NaN             ICE
# ...               ...             ...       ...         ...             ...
# 2019               T1         Unknown    Diesel         NaN             ICE
# 2019               MH  Not Applicable    Diesel         NaN             ICE
# 2019               MC  Not Applicable    Diesel         NaN             ICE
# 2019                B  Not Applicable    Diesel         NaN             ICE
# 2019                B  Not Applicable    Diesel         NaN             ICE
#
# ...

# %%
df.shape
# Out:
# (41053, 9)

# %%
df.dropna(inplace=True)

# %%
df.isna().any()
# Out:
# Vehicle Category                                     False
# GVWR Class                                           False
# Fuel Type                                            False
# Model Year                                           False
# Fuel Technology                                      False
# Electric Mile Range                                  False
# Number of Vehicles Registered at the Same Address    False
# Region                                               False
# Vehicle Population                                   False
# dtype: bool

# %%
df.isin([-np.inf,np.inf]).any()
# Out:
# Vehicle Category                                     False
# GVWR Class                                           False
# Fuel Type                                            False
# Model Year                                           False
# Fuel Technology                                      False
# Electric Mile Range                                  False
# Number of Vehicles Registered at the Same Address    False
# Region                                               False
# Vehicle Population                                   False
# dtype: bool

# %%
# Checking for redundant columns
df['Region'].unique()
# Out:
# array(['Statewide'], dtype=object)

# %%
df.drop(['Region'],axis=1,inplace=True)

# %%
df.head()
# Out:
#      Vehicle Category      GVWR Class Fuel Type  Model Year Fuel Technology  \
# Date
# 2019                P  Not Applicable  Gasoline      2020.0             ICE
# 2020                P  Not Applicable  Gasoline      2020.0             ICE
# 2021                P  Not Applicable  Gasoline      2020.0             ICE
# 2019                P  Not Applicable  Gasoline      2019.0             ICE
# 2019                P  Not Applicable  Gasoline      2018.0             ICE
#
#      Electric Mile Range Number of Vehicles Registered at the Same Address  \
# Date
# 2019      Not Applicable                                                ≥4
# 2020      Not Applicable                                                 1
# 2021      Not Applicable                                                 1
# 2019      Not Applicable                                                ≥4
# 2019      Not Applicable                                                ≥4
#
#       Vehicle Population
# Date
# ...

# %%
df['Model Year'] = df['Model Year'].astype('Int64')

# %%
df.to_csv("../data/processed/processed-without-impute.csv")
