# %%
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import root_mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
import numpy as np

# %%
df = pd.read_csv("../../data/processed/encoded_dataset-non-impute.csv",index_col=0)

# %%
df.head()
# Out:
#       GVWR Class  Model Year  Electric Mile Range  \
# Date
# 2019           0        2020                    0
# 2020           0        2020                    0
# 2021           0        2020                    0
# 2019           0        2019                    0
# 2019           0        2018                    0
#
#       Number of Vehicles Registered at the Same Address  Vehicle Population  \
# Date
# 2019                                                  4              395883
# 2020                                                  1              370954
# 2021                                                  1              349406
# 2019                                                  4              348475
# 2019                                                  4              333296
#
#       Vehicle Category_BS  Vehicle Category_BT  Vehicle Category_MC  \
# Date
# 2019                False                False                False
# 2020                False                False                False
# 2021                False                False                False
# 2019                False                False                False
# 2019                False                False                False
#
#       Vehicle Category_MH  Vehicle Category_P  ...  Vehicle Category_T6  \
# Date                                           ...
# 2019                False                True  ...                False
# 2020                False                True  ...                False
# 2021                False                True  ...                False
# 2019                False                True  ...                False
# 2019                False                True  ...                False
#
#       Vehicle Category_T7  Fuel Type_Electric  Fuel Type_Gasoline  \
# Date
# 2019                False               False                True
# 2020                False               False                True
# 2021                False               False                True
# 2019                False               False                True
# 2019                False               False                True
#
#       Fuel Type_Hydrogen  Fuel Type_Natural Gas  Fuel Type_Unknown  \
# Date
# 2019               False                  False              False
# 2020               False                  False              False
# 2021               False                  False              False
# 2019               False                  False              False
# 2019               False                  False              False
#
#       Fuel Technology_FCEV  Fuel Technology_ICE  Fuel Technology_PHEV
# Date
# 2019                 False                 True                 False
# 2020                 False                 True                 False
# 2021                 False                 True                 False
# 2019                 False                 True                 False
# 2019                 False                 True                 False
#
# [5 rows x 25 columns]

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_f93e8_row0_col0, #T_f93e8_row1_col1, #T_f93e8_row2_col2, #T_f93e8_row3_col3, #T_f93e8_row4_col4, #T_f93e8_row5_col5, #T_f93e8_row6_col6, #T_f93e8_row7_col7, #T_f93e8_row8_col8, #T_f93e8_row9_col9, #T_f93e8_row10_col10, #T_f93e8_row11_col11, #T_f93e8_row12_col12, #T_f93e8_row13_col13, #T_f93e8_row14_col14, #T_f93e8_row15_col15, #T_f93e8_row16_col16, #T_f93e8_row17_col17, #T_f93e8_row18_col18, #T_f93e8_row19_col19, #T_f93e8_row19_col22, #T_f93e8_row20_col20, #T_f93e8_row21_col21, #T_f93e8_row22_col19, #T_f93e8_row22_col22, #T_f93e8_row23_col23, #T_f93e8_row24_col24 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f93e8_row0_col1, #T_f93e8_row5_col1, #T_f93e8_row14_col1, #T_f93e8_row17_col11, #T_f93e8_row20_col12, #T_f93e8_row21_col2 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_f93e8_row0_col2, #T_f93e8_row6_col9, #T_f93e8_row7_col1, #T_f93e8_row7_col9, #T_f93e8_row8_col9, #T_f93e8_row19_col18, #T_f93e8_row20_col5, #T_f93e8_row22_col18, #T_f93e8_row23_col8, #T_f93e8_row24_col12 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_f93e8_row0_
{
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_f93e8_row1_col13, #T_f93e8_row2_col12, #T_f93e8_row2_col13, #T_f93e8_row12_col19, #T_f93e8_row12_col22, #T_f93e8_row13_col19, #T_f93e8_row13_col22, #T_f93e8_row17_col19, #T_f93e8_row17_col22, #T_f93e8_row19_col0, #T_f93e8_row19_col12, #T_f93e8_row19_col13, #T_f93e8_row20_col19, #T_f93e8_row20_col22, #T_f93e8_row21_col0, #T_f93e8_row21_col13, #T_f93e8_row22_col0, #T_f93e8_row22_col12, #T_f93e8_row22_col13, #T_f93e8_row23_col4 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_f93e8_row1_col14, #T_f93e8_row3_col8, #T_f93e8_row10_col1, #T_f93e8_row18_col19, #T_f93e8_row18_col22, #T_f93e8_row19_col7, #T_f93e8_row19_col8, #T_f93e8_row22_col7, #T_f93e8_row22_col8 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_f93e8_row1_col17 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_f93e8_row1_col18 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_f93e8_row1_col19, #T_f93e8_row1_col22, #T_f93e8_row15_col24, #T_f93e8_row18_col2 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_f93e8_row1_col20 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_f93e8_row1_col21, #T_f93e8_row4_col5, #T_f93e8_row4_col8, #T_f93e8_row5_col12, #T_f93e8_row5_col13, #T_f93e8_row7_col2, #T_f93e8_row7_col13, #T_f93e8_r

# %%
# Random Forest Feature Importance
rf = RandomForestRegressor(max_depth=50, n_estimators=150, random_state=42)

# %%
X = df.drop(['Vehicle Population'],axis=1)

# %%
y = df['Vehicle Population']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=50, n_estimators=150, random_state=42)

# %%
# Evaluate
y_pred = rf.predict(X_test)
print(f"RMSE: {root_mean_squared_error(y_test, y_pred)}")
print(f"R²: {r2_score(y_test, y_pred)}")
# Out:
# RMSE: 5849.220931790117
# R²: 0.901691369672935

# %%
feature_importances = rf.feature_importances_
feature_names = X_train.columns

# %%
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# Plot the feature importance
plt.figure(figsize=(12, 6))
plt.bar(importance_df['Feature'], importance_df['Importance'])
plt.xlabel('Feature')
plt.ylabel('Importance Score')
plt.title('Random Forest Feature Importance')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
X = df[['Model Year','Fuel Technology_ICE','Fuel Type_Gasoline',' Vehicle Category_P','Number of Vehicles Registered at the Same Adddress]]

# %%
X
# Out:
#       Model Year  Fuel Technology_ICE  Fuel Type_Gasoline
# Date
# 2019        2020                 True                True
# 2020        2020                 True                True
# 2021        2020                 True                True
# 2019        2019                 True                True
# 2019        2018                 True                True
# ...          ...                  ...                 ...
# 2019        1983                 True               False
# 2019        1980                 True               False
# 2019        1978                 True               False
# 2019        1976                 True               False
# 2019        1976                 True               False
#
# [40450 rows x 3 columns]

# %%
y
# Out:
# Date
# 2019    395883
# 2020    370954
# 2021    349406
# 2019    348475
# 2019    333296
#          ...
# 2019         1
# 2019         1
# 2019         1
# 2019         1
# 2019         1
# Name: Vehicle Population, Length: 40450, dtype: int64

# %%
model2 = RandomForestRegressor(max_depth=50, n_estimators=150, random_state=42)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
model2.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=50, n_estimators=150, random_state=42)

# %%
y_pred = model2.predict(X_test)

# %%
root_mean_squared_error(y_test,y_pred)
# Out:
# np.float64(17639.59358306282)
