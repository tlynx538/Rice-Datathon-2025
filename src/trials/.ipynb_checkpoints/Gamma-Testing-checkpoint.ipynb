# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import GammaRegressor
from sklearn.metrics import root_mean_squared_error

# %%
df = pd.read_csv("../data/processed/removed-unn-corr.csv",index_col=0)

# %%
df.head()
# Out:
#       GVWR Class  Model Year  Electric Mile Range  \
# Date
# 2019           0        2020                    0
# 2020           0        2020                    0
# 2021           0        2020                    0
# 2019           0        2019                    0
# 2019           0        2018                    0
#
#       Number of Vehicles Registered at the Same Address  Vehicle Population  \
# Date
# 2019                                                  4              395883
# 2020                                                  1              370954
# 2021                                                  1              349406
# 2019                                                  4              348475
# 2019                                                  4              333296
#
#       Vehicle Category_BS  Vehicle Category_BT  Vehicle Category_MC  \
# Date
# 2019                False                False                False
# 2020                False                False                False
# 2021                False                False                False
# 2019                False                False                False
# 2019                False                False                False
#
#       Vehicle Category_MH  Vehicle Category_P  ...  Vehicle Category_T2  \
# Date                                           ...
# 2019                False                True  ...                False
# 2020                False                True  ...                False
# 2021                False                True  ...                False
# 2019                False                True  ...                False
# 2019                False                True  ...                False
#
#       Vehicle Category_T3  Vehicle Category_T4  Vehicle Category_T5  \
# Date
# 2019                False                False                False
# 2020                False                False                False
# 2021                False                False                False
# 2019                False                False                False
# 2019                False                False                False
#
#       Vehicle Category_T6  Vehicle Category_T7  Fuel Type_Gasoline  \
# Date
# 2019                False                False                True
# 2020                False                False                True
# 2021                False                False                True
# 2019                False                False                True
# 2019                False                False                True
#
#       Fuel Type_Natural Gas  Fuel Type_Unknown  Fuel Technology_PHEV
# Date
# 2019                  False              False                 False
# 2020                  False              False                 False
# 2021                  False              False                 False
# 2019                  False              False                 False
# 2019                  False              False                 False
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (40450, 21)

# %%
X = df.drop(['Vehicle Population'],axis=1)

# %%
y = df['Vehicle Population']

# %%
model = GammaRegressor(max_iter=100000)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1675)

# %%
model.fit(X_train,y_train)
# Out:
# GammaRegressor(max_iter=100000)

# %%
y_pred = model.predict(X_test)

# %%
root_mean_squared_error(y_test,y_pred)
# Out:
# np.float64(17332.00262883392)
